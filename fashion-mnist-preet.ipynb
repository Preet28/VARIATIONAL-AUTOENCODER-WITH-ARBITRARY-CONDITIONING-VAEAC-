# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fashion-mnist/__results__.html
# /kaggle/input/fashion-mnist/__output__.json
# /kaggle/input/fashion-mnist/custom.css
# /kaggle/input/fashion-mnist/models/deep1/graph.pbtxt
# /kaggle/input/fashion-mnist/models/deep1/model.ckpt-1.meta
# /kaggle/input/fashion-mnist/models/deep1/model.ckpt-1.index
# /kaggle/input/fashion-mnist/models/deep1/model.ckpt-1800.data-00000-of-00001
# /kaggle/input/fashion-mnist/models/deep1/model.ckpt-1.data-00000-of-00001
# /kaggle/input/fashion-mnist/models/deep1/events.out.tfevents.1523949381.9e78698532fd
# /kaggle/input/fashion-mnist/models/deep1/model.ckpt-1800.meta
# /kaggle/input/fashion-mnist/models/deep1/checkpoint
# /kaggle/input/fashion-mnist/models/deep1/model.ckpt-1800.index
# /kaggle/input/fashion-mnist/models/deep1/eval/events.out.tfevents.1523949388.9e78698532fd
# /kaggle/input/fashion-mnist/models/linear1/graph.pbtxt
# /kaggle/input/fashion-mnist/models/linear1/model.ckpt-1.meta
# /kaggle/input/fashion-mnist/models/linear1/model.ckpt-1.index
# /kaggle/input/fashion-mnist/models/linear1/model.ckpt-1800.data-00000-of-00001
# /kaggle/input/fashion-mnist/models/linear1/model.ckpt-1.data-00000-of-00001
# /kaggle/input/fashion-mnist/models/linear1/model.ckpt-1800.meta
# /kaggle/input/fashion-mnist/models/linear1/checkpoint
# /kaggle/input/fashion-mnist/models/linear1/model.ckpt-1800.index
# /kaggle/input/fashion-mnist/models/linear1/events.out.tfevents.1523949374.9e78698532fd
# /kaggle/input/fashion-mnist/models/linear1/eval/events.out.tfevents.1523949379.9e78698532fd
# /kaggle/input/fashion-mnist/__results___files/__results___16_2.png
# /kaggle/input/fashion-mnist/__results___files/__results___16_4.png
# /kaggle/input/fashion-mnist/__results___files/__results___16_3.png
# /kaggle/input/fashion-mnist/__results___files/__results___16_0.png
# /kaggle/input/fashion-mnist/__results___files/__results___16_1.png

# %%
# ============================================
# 1. Imports and Setup
# ============================================
import os
import random
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm



# Use GPU if available (Kaggle GPU runtime)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on:", device)
# Out:
# Running on: cuda

# %%
# ============================================
# 2. Set up directories (Kaggle paths)
# ============================================
base_dir = "/kaggle/working"
data_dir = os.path.join(base_dir, "data")

# Folder structure
train_orig_dir = os.path.join(data_dir, "train", "original")
train_masked_dir = os.path.join(data_dir, "train", "masked")
train_mask_dir = os.path.join(data_dir, "train", "mask")

test_orig_dir = os.path.join(data_dir, "test", "original")
test_masked_dir = os.path.join(data_dir, "test", "masked")
test_mask_dir = os.path.join(data_dir, "test", "mask")

checkpoint_dir = os.path.join(data_dir, "vaeac_checkpoints")
results_dir = os.path.join(data_dir, "results")

# Create directories
for d in [
    train_orig_dir, train_masked_dir, train_mask_dir,
    test_orig_dir, test_masked_dir, test_mask_dir,
    checkpoint_dir, results_dir
]:
    os.makedirs(d, exist_ok=True)
print("Directories ready at:", data_dir)
# Out:
# Directories ready at: /kaggle/working/data

# %%
# ============================================
# 3. Load Fashion-MNIST Dataset
# ============================================
transform_to_tensor = transforms.ToTensor()

train_dataset_raw = datasets.FashionMNIST(
    root=data_dir,
    train=True,
    download=True,
    transform=transform_to_tensor
)

test_dataset_raw = datasets.FashionMNIST(
    root=data_dir,
    train=False,
    download=True,
    transform=transform_to_tensor
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 12.2MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 273kB/s]
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 4.51MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 24.6MB/s]

# %%
# ============================================
# 4. Mask generation utilities
# ============================================
IMG_H, IMG_W = 28, 28

def generate_rect_mask(h, w, area_frac=0.3):
    total = h * w
    target_missing = max(1, int(total * area_frac))
    for _ in range(20):
        rect_h = random.randint(1, h)
        rect_w = max(1, target_missing // rect_h)
        if rect_w <= w:
            break
    rect_h, rect_w = min(rect_h, h), min(rect_w, w)
    top, left = random.randint(0, h - rect_h), random.randint(0, w - rect_w)
    mask = np.ones((h, w), dtype=np.uint8)
    mask[top:top+rect_h, left:left+rect_w] = 0
    return mask

def apply_mask_pil(pil_img, mask):
    arr = np.array(pil_img).astype(np.uint8)
    masked = arr * mask
    return Image.fromarray(masked.astype(np.uint8))

# %%
# ============================================
# 5. Save images into clean folder structure
# ============================================
def save_masked_images(dataset, orig_dir, masked_dir, mask_dir, split="train"):
    if len(os.listdir(orig_dir)) == 0:
        print(f"Generating {split} images...")
        for i, (img_tensor, label) in enumerate(tqdm(dataset, desc=f"{split.capitalize()} Set")):
            img_np = (img_tensor.squeeze(0).numpy() * 255).astype(np.uint8)
            pil_img = Image.fromarray(img_np, mode="L")

            mask = generate_rect_mask(IMG_H, IMG_W, area_frac=0.3)
            masked_img = apply_mask_pil(pil_img, mask)

            fname = f"{i:05d}.png"
            pil_img.save(os.path.join(orig_dir, fname))
            masked_img.save(os.path.join(masked_dir, fname))
            Image.fromarray((mask * 255).astype(np.uint8)).save(os.path.join(mask_dir, fname))
        print(f"{split.capitalize()} images saved successfully.")
    else:
        print(f"{split.capitalize()} data already exists — skipping generation.")

# Generate both splits
save_masked_images(train_dataset_raw, train_orig_dir, train_masked_dir, train_mask_dir, "train")
save_masked_images(test_dataset_raw, test_orig_dir, test_masked_dir, test_mask_dir, "test")
# Out:
# Generating train images...
# Train Set:   0%|          | 0/60000 [00:00<?, ?it/s]/tmp/ipykernel_47/6677344.py:9: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   pil_img = Image.fromarray(img_np, mode="L")
# Train Set: 100%|██████████| 60000/60000 [00:53<00:00, 1117.83it/s]
# Train images saved successfully.
# Generating test images...
# Test Set: 100%|██████████| 10000/10000 [00:09<00:00, 1075.29it/s]
# Test images saved successfully.

# %%
# ============================================
# 6. Dataset Class (optimized)
# ============================================
class MaskedMNISTDataset(Dataset):
    def __init__(self, orig_dir, masked_dir, mask_dir, transform=None):
        self.orig_dir = orig_dir
        self.masked_dir = masked_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.filenames = sorted(os.listdir(orig_dir))

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        fname = self.filenames[idx]
        orig = Image.open(os.path.join(self.orig_dir, fname)).convert("L")
        masked = Image.open(os.path.join(self.masked_dir, fname)).convert("L")
        mask = Image.open(os.path.join(self.mask_dir, fname)).convert("L")

        if self.transform:
            orig = self.transform(orig)
            masked = self.transform(masked)
            mask = self.transform(mask)

        mask = (mask > 0.5).float()
        return orig, masked, mask

# %%
# ============================================
# 7. Model Definition (VAEAC)
# ============================================
latent_dim = 16

class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 4, 2, 1),
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, 2, 1),
            nn.ReLU()
        )
        self.fc_mu = nn.Linear(64*7*7, latent_dim)
        self.fc_logvar = nn.Linear(64*7*7, latent_dim)
    def forward(self, x):
        h = self.conv(x).view(x.size(0), -1)
        return self.fc_mu(h), self.fc_logvar(h)

class Prior(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(2, 32, 4, 2, 1),
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, 2, 1),
            nn.ReLU()
        )
        self.fc_mu = nn.Linear(64*7*7, latent_dim)
        self.fc_logvar = nn.Linear(64*7*7, latent_dim)
    def forward(self, x_b, b):
        xb = torch.cat([x_b, b], dim=1)
        h = self.conv(xb).view(xb.size(0), -1)
        return self.fc_mu(h), self.fc_logvar(h)

class Decoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.fc = nn.Linear(latent_dim + 2*IMG_H*IMG_W, 64*7*7)
        self.deconv = nn.Sequential(
            nn.ConvTranspose2d(64, 32, 4, 2, 1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 1, 4, 2, 1),
            nn.Sigmoid()
        )
    def forward(self, z, x_b, b):
        xb_flat = torch.cat([x_b.view(x_b.size(0), -1), b.view(b.size(0), -1)], dim=1)
        h = torch.cat([z, xb_flat], dim=1)
        h = self.fc(h).view(h.size(0), 64, 7, 7)
        return self.deconv(h)

class VAEAC(nn.Module):
    def __init__(self, latent_dim=16):
        super().__init__()
        self.encoder = Encoder(latent_dim)
        self.prior = Prior(latent_dim)
        self.decoder = Decoder(latent_dim)
    def forward(self, x, x_b, b):
        mu_q, logvar_q = self.encoder(x)
        std = torch.exp(0.5 * logvar_q)
        z = mu_q + torch.randn_like(std) * std
        mu_p, logvar_p = self.prior(x_b, b)
        x_recon = self.decoder(z, x_b, b)
        return x_recon, mu_p, logvar_p, mu_q, logvar_q

# %%
# ============================================
# 8. Loss Function
# ============================================
def vaeac_loss(recon_x, x, mu, logvar, mask):
    missing = 1.0 - mask
    bce = F.binary_cross_entropy(recon_x * missing, x * missing, reduction="sum")
    kl = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return bce + kl

# %%
# ============================================
# 9. Training Setup
# ============================================
batch_size = 128
epochs = 25
learning_rate = 1e-3

train_dataset = MaskedMNISTDataset(train_orig_dir, train_masked_dir, train_mask_dir, transform=transforms.ToTensor())
test_dataset  = MaskedMNISTDataset(test_orig_dir, test_masked_dir, test_mask_dir, transform=transforms.ToTensor())

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

vaeac = VAEAC(latent_dim).to(device)
optimizer = torch.optim.Adam(vaeac.parameters(), lr=learning_rate)

# %%
# ============================================
# 10. Training Loop
# ============================================
for epoch in range(epochs):
    vaeac.train()
    total_loss = 0
    print(f"\nEpoch {epoch+1}/{epochs}")
    for data, masked, mask in tqdm(train_loader, desc=f"Training Epoch {epoch+1}", leave=False):
        data, masked, mask = data.to(device), masked.to(device), mask.to(device)
        optimizer.zero_grad()
        recon, mu_p, logvar_p, mu_q, logvar_q = vaeac(data, masked, mask)
        loss = vaeac_loss(recon, data, mu_q, logvar_q, mask)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    avg_loss = total_loss / len(train_loader.dataset)
    print(f"Epoch {epoch+1} completed. Avg Loss: {avg_loss:.4f}")
    torch.save(vaeac.state_dict(), os.path.join(checkpoint_dir, f"vaeac_epoch_{epoch+1}.pth"))
# Out:
# Epoch 1/25
# Epoch 1 completed. Avg Loss: 101.5373
#
# Epoch 2/25
# Epoch 2 completed. Avg Loss: 95.0275
#
# Epoch 3/25
# Epoch 3 completed. Avg Loss: 93.3751
#
# Epoch 4/25
# Epoch 4 completed. Avg Loss: 92.4265
#
# Epoch 5/25
# Epoch 5 completed. Avg Loss: 91.7856
#
# Epoch 6/25
# Epoch 6 completed. Avg Loss: 91.2432
#
# Epoch 7/25
# Epoch 7 completed. Avg Loss: 90.8397
#
# Epoch 8/25
# Epoch 8 completed. Avg Loss: 90.4913
#
# Epoch 9/25
# Epoch 9 completed. Avg Loss: 90.2469
#
# Epoch 10/25
# Epoch 10 completed. Avg Loss: 89.9051
#
# Epoch 11/25
# Epoch 11 completed. Avg Loss: 89.6965
#
# Epoch 12/25
# Epoch 12 completed. Avg Loss: 89.4814
#
# Epoch 13/25
# Epoch 13 completed. Avg Loss: 89.2754
#
# Epoch 14/25
# Epoch 14 completed. Avg Loss: 89.1291
#
# Epoch 15/25
# Epoch 15 completed. Avg Loss: 88.9806
#
# Epoch 16/25
# Epoch 16 completed. Avg Loss: 88.7538
#
# Epoch 17/25
# Epoch 17 completed. Avg Loss: 88.6196
#
# Epoch 18/25
# Epoch 18 completed. Avg Loss: 88.4540
#
# Epoch 19/25
# Epoch 19 completed. Avg Loss: 88.3496
#
# Epoch 20/25
# Epoch 20 completed. Avg Loss: 88.1987
#
# Epoch 21/25
# Epoch 21 completed. Avg Loss: 88.0881
#
# Epoch 22/25
# Epoch 22 completed. Avg Loss: 87.9388
#
# Epoch 23/25
# Epoch 23 completed. Avg Loss: 87.7771
#
# Epoch 24/25
# Epoch 24 completed. Avg Loss: 87.7053
#
# Epoch 25/25
# Epoch 25 completed. Avg Loss: 87.5423

# %%
# ============================================
# 11. Visualization + Save ALL Test Predictions
# ============================================
vaeac.eval()
save_dir = results_dir  # /kaggle/working/data/results
os.makedirs(save_dir, exist_ok=True)

print(f"Saving all reconstructed test samples to: {save_dir}")

to_display = []  # store a few random samples for visualization
with torch.no_grad():
    sample_idx = 0
    for batch_idx, (data, masked, mask) in enumerate(tqdm(test_loader, desc="Saving Predictions")):
        data, masked, mask = data.to(device), masked.to(device), mask.to(device)
        recon, *_ = vaeac(data, masked, mask)

        batch_size_now = data.size(0)
        for i in range(batch_size_now):
            orig = (data[i].cpu().squeeze(0).numpy() * 255).astype(np.uint8)
            masked_img = (masked[i].cpu().squeeze(0).numpy() * 255).astype(np.uint8)
            recon_img = (recon[i].cpu().squeeze(0).numpy() * 255).astype(np.uint8)
            mask_img = (mask[i].cpu().squeeze(0).numpy() * 255).astype(np.uint8)

            # Combine horizontally: Mask | Masked | Reconstructed | Original
            concat = np.concatenate([mask_img, masked_img, recon_img, orig], axis=1)
            Image.fromarray(concat).save(os.path.join(save_dir, f"result_{sample_idx:05d}.png"))

            # randomly pick a few samples for visualization
            if len(to_display) < 8 and random.random() < 0.01:
                to_display.append(concat)

            sample_idx += 1

print(f"✅ Saved {sample_idx} reconstructed test samples to: {save_dir}")
# Out:
# Saving all reconstructed test samples to: /kaggle/working/data/results
# Saving Predictions: 100%|██████████| 79/79 [00:06<00:00, 11.68it/s]
# ✅ Saved 10000 reconstructed test samples to: /kaggle/working/data/results

# %%
# ============================================
# Display a few random predictions
# ============================================
if len(to_display) > 0:
    print("\nDisplaying a few sample reconstructions:")
    plt.figure(figsize=(8, 4))
    for idx, img in enumerate(to_display[:4]):
        plt.subplot(len(to_display[:4]), 1, idx + 1)
        plt.imshow(img, cmap='gray')
        plt.axis('off')
        if idx == 0:
            plt.title("Mask | Masked | Reconstructed | Original", fontsize=10)
    plt.tight_layout()
    plt.show()
else:
    print("No samples selected for display.")
# Out:
# Displaying a few sample reconstructions:

# %%
# !zip -r /kaggle/working/output.zip /kaggle/working/* && echo "Zipped all files — download 'output.zip' from the sidebar → Files tab."
# Out:
#   adding: kaggle/working/data/ (stored 0%)
#   adding: kaggle/working/data/vaeac_checkpoints/ (stored 0%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_14.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_6.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_12.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_21.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_25.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_22.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_3.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_23.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_19.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_1.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_7.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_9.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_13.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_17.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_11.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_2.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_15.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_16.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_4.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_8.pth (deflated 7%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_24.pth (deflated 6%)
#   adding: kaggle/working/data/vaeac_checkpoints/vaeac_epoch_5.pth
